# %%
import pandas as pd

# %%
Bank_data = pd.read_csv("dataset/European_Bank (1).csv")

# %%
Bank_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  str
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  str
#  5   Gender           10000 non-null  str
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), str(3)
# memory usage: 1.1 MB

# %%
Bank_data.head()
# Out:
#    Year  CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0  2025    15634602  Hargrave          619    France  Female   42       2
# 1  2025    15647311      Hill          608     Spain  Female   41       1
# 2  2025    15619304      Onio          502    France  Female   42       8
# 3  2025    15701354      Boni          699    France  Female   39       1
# 4  2025    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
Bank_data.tail()
# Out:
#       Year  CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 9995  2025    15606229   Obijiaku          771    France    Male   39       5
# 9996  2025    15569892  Johnstone          516    France    Male   35      10
# 9997  2025    15584532        Liu          709    France  Female   36       7
# 9998  2025    15682355  Sabbatini          772   Germany    Male   42       3
# 9999  2025    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 9995       0.00              2          1               0         96270.64
# 9996   57369.61              1          1               1        101699.77
# 9997       0.00              1          0               1         42085.58
# 9998   75075.31              2          1               0         92888.52
# 9999  130142.79              1          1               0         38190.78
#
#       Exited
# 9995       0
# 9996       0
# ...

# %%
Bank_data.isnull().sum()
# Out:
# Year               0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
Bank_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
Bank_data.duplicated(keep= False)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
Bank_data.describe()
# Out:
#           Year    CustomerId   CreditScore           Age        Tenure  \
# count  10000.0  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    2025.0  1.569094e+07    650.528800     38.921800      5.012800
# std        0.0  7.193619e+04     96.653299     10.487806      2.892174
# min     2025.0  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2025.0  1.562853e+07    584.000000     32.000000      3.000000
# 50%     2025.0  1.569074e+07    652.000000     37.000000      5.000000
# 75%     2025.0  1.575323e+07    718.000000     44.000000      7.000000
# max     2025.0  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# ...

# %%
Bank_data.drop(columns = "Surname")
# Out:
#       Year  CustomerId  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0     2025    15634602          619    France  Female   42       2       0.00
# 1     2025    15647311          608     Spain  Female   41       1   83807.86
# 2     2025    15619304          502    France  Female   42       8  159660.80
# 3     2025    15701354          699    France  Female   39       1       0.00
# 4     2025    15737888          850     Spain  Female   43       2  125510.82
# ...    ...         ...          ...       ...     ...  ...     ...        ...
# 9995  2025    15606229          771    France    Male   39       5       0.00
# 9996  2025    15569892          516    France    Male   35      10   57369.61
# 9997  2025    15584532          709    France  Female   36       7       0.00
# 9998  2025    15682355          772   Germany    Male   42       3   75075.31
# 9999  2025    15628319          792    France  Female   28       4  130142.79
#
# ...

# %%
Bank_data.groupby("Exited")["Balance"].mean()
# Out:
# Exited
# 0    72745.296779
# 1    91108.539337
# Name: Balance, dtype: float64

# %%
Bank_data.groupby("Exited")["NumOfProducts"].mean()
# Out:
# Exited
# 0    1.544267
# 1    1.475209
# Name: NumOfProducts, dtype: float64

# %%
Bank_data.groupby("Exited")["IsActiveMember"].mean()
# Out:
# Exited
# 0    0.554565
# 1    0.360825
# Name: IsActiveMember, dtype: float64

# %%
Bank_data.groupby("Exited")["EstimatedSalary"].mean()
# Out:
# Exited
# 0     99738.391772
# 1    101465.677531
# Name: EstimatedSalary, dtype: float64

# %%
Bank_data.groupby("Exited")["Age"].mean()
# Out:
# Exited
# 0    37.408389
# 1    44.837997
# Name: Age, dtype: float64

# %%
Bank_data.drop(columns="Surname")
# Out:
#       Year  CustomerId  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0     2025    15634602          619    France  Female   42       2       0.00
# 1     2025    15647311          608     Spain  Female   41       1   83807.86
# 2     2025    15619304          502    France  Female   42       8  159660.80
# 3     2025    15701354          699    France  Female   39       1       0.00
# 4     2025    15737888          850     Spain  Female   43       2  125510.82
# ...    ...         ...          ...       ...     ...  ...     ...        ...
# 9995  2025    15606229          771    France    Male   39       5       0.00
# 9996  2025    15569892          516    France    Male   35      10   57369.61
# 9997  2025    15584532          709    France  Female   36       7       0.00
# 9998  2025    15682355          772   Germany    Male   42       3   75075.31
# 9999  2025    15628319          792    France  Female   28       4  130142.79
#
# ...

# %%
Bank_data.groupby(["Geography"])["Exited"].value_counts(normalize= True).loc[:, 1]*100
# Out:
# Geography
# France     16.154767
# Germany    32.443204
# Spain      16.673395
# Name: proportion, dtype: float64

# %%
Bins = [0,30,45,60,100]     # bins he lablel peksha 1 ni jasta pahije

Labels =["<30","31-45","46-60",">60"]

Bank_data["Age_group"] = pd.cut(Bank_data["Age"],bins=Bins,labels=Labels)

Bank_data
# Out:
#       Year  CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0     2025    15634602   Hargrave          619    France  Female   42       2
# 1     2025    15647311       Hill          608     Spain  Female   41       1
# 2     2025    15619304       Onio          502    France  Female   42       8
# 3     2025    15701354       Boni          699    France  Female   39       1
# 4     2025    15737888   Mitchell          850     Spain  Female   43       2
# ...    ...         ...        ...          ...       ...     ...  ...     ...
# 9995  2025    15606229   Obijiaku          771    France    Male   39       5
# 9996  2025    15569892  Johnstone          516    France    Male   35      10
# 9997  2025    15584532        Liu          709    France  Female   36       7
# 9998  2025    15682355  Sabbatini          772   Germany    Male   42       3
# 9999  2025    15628319     Walker          792    France  Female   28       4
#
# ...

# %%
Bank_data.groupby("Age")["Age"].value_counts()
# Out:
# Age
# 18    22
# 19    27
# 20    40
# 21    53
# 22    84
#       ..
# 83     1
# 84     2
# 85     1
# 88     1
# 92     2
# Name: count, Length: 70, dtype: int64

# %%
Bank_data.groupby("Age_group")["Exited"].value_counts(normalize = True).loc[:,1]*100
# Out:
# Age_group
# <30       7.520325
# 31-45    15.740584
# 46-60    51.123254
# >60      24.784483
# Name: proportion, dtype: float64

# %%
Bank_data.groupby(["Age_group","Geography"])["Exited"].value_counts(normalize = True).loc[:,:,1]*100
# Out:
# Age_group  Geography
# <30        France        4.913295
#            Germany      12.362031
#            Spain         8.595388
# 31-45      France       12.349800
#            Germany      26.092991
#            Spain        12.533693
# 46-60      France       45.794393
#            Germany      67.330677
#            Spain        40.656566
# >60        France       19.913420
#            Germany      38.938053
#            Spain        20.833333
# Name: proportion, dtype: float64

# %%
Bins = [300,670,740,850]

Labels = ["Low","Medium","High"]

Bank_data["CreditScore_group"]= pd.cut(Bank_data["CreditScore"],bins=Bins,labels=Labels)

# %%
Bank_data
# Out:
#       Year  CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0     2025    15634602   Hargrave          619    France  Female   42       2
# 1     2025    15647311       Hill          608     Spain  Female   41       1
# 2     2025    15619304       Onio          502    France  Female   42       8
# 3     2025    15701354       Boni          699    France  Female   39       1
# 4     2025    15737888   Mitchell          850     Spain  Female   43       2
# ...    ...         ...        ...          ...       ...     ...  ...     ...
# 9995  2025    15606229   Obijiaku          771    France    Male   39       5
# 9996  2025    15569892  Johnstone          516    France    Male   35      10
# 9997  2025    15584532        Liu          709    France  Female   36       7
# 9998  2025    15682355  Sabbatini          772   Germany    Male   42       3
# 9999  2025    15628319     Walker          792    France  Female   28       4
#
# ...

# %%
Bank_data["Balance"].max()
# Out:
# np.float64(250898.09)

# %%
Bank_data["Tenure"].max()
# Out:
# np.int64(10)

# %%
Bank_data["Tenure"].mean()
# Out:
# np.float64(5.0128)

# %%
Bank_data["Tenure"].min()
# Out:
# np.int64(0)

# %%
Bins = [-1,2,5,10]

Labels = ["New_customer","Mid term","Long term"]

Bank_data["Tenure_group"] = pd.cut(Bank_data["Tenure"],bins=Bins,labels=Labels)

Bank_data
# Out:
#       Year  CustomerId  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0     2025    15634602          619    France  Female   42       2       0.00
# 1     2025    15647311          608     Spain  Female   41       1   83807.86
# 2     2025    15619304          502    France  Female   42       8  159660.80
# 3     2025    15701354          699    France  Female   39       1       0.00
# 4     2025    15737888          850     Spain  Female   43       2  125510.82
# ...    ...         ...          ...       ...     ...  ...     ...        ...
# 9995  2025    15606229          771    France    Male   39       5       0.00
# 9996  2025    15569892          516    France    Male   35      10   57369.61
# 9997  2025    15584532          709    France  Female   36       7       0.00
# 9998  2025    15682355          772   Germany    Male   42       3   75075.31
# 9999  2025    15628319          792    France  Female   28       4  130142.79
#
# ...

# %%
Bank_data["Balance"].max()
# Out:
# np.float64(250898.09)

# %%
Bank_data["Balance"].min()
# Out:
# np.float64(0.0)

# %%
Bank_data["Balance"].mean()
# Out:
# np.float64(76485.889288)

# %%
Bins = [-1,50000,150000,float("inf")]

Labels = ["zero_balance","Min_balance","High_balance"]

Bank_data["Balance_group"] = pd.cut(Bank_data["Balance"],labels= Labels,bins = Bins)

# %%
Bank_data
# Out:
#       Year  CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0     2025    15634602   Hargrave          619    France  Female   42       2
# 1     2025    15647311       Hill          608     Spain  Female   41       1
# 2     2025    15619304       Onio          502    France  Female   42       8
# 3     2025    15701354       Boni          699    France  Female   39       1
# 4     2025    15737888   Mitchell          850     Spain  Female   43       2
# ...    ...         ...        ...          ...       ...     ...  ...     ...
# 9995  2025    15606229   Obijiaku          771    France    Male   39       5
# 9996  2025    15569892  Johnstone          516    France    Male   35      10
# 9997  2025    15584532        Liu          709    France  Female   36       7
# 9998  2025    15682355  Sabbatini          772   Germany    Male   42       3
# 9999  2025    15628319     Walker          792    France  Female   28       4
#
# ...

# %%
Bank_data.drop(columns="Surname",inplace=True)

# %%
Bank_data
# Out:
#       Year  CustomerId  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0     2025    15634602          619    France  Female   42       2       0.00
# 1     2025    15647311          608     Spain  Female   41       1   83807.86
# 2     2025    15619304          502    France  Female   42       8  159660.80
# 3     2025    15701354          699    France  Female   39       1       0.00
# 4     2025    15737888          850     Spain  Female   43       2  125510.82
# ...    ...         ...          ...       ...     ...  ...     ...        ...
# 9995  2025    15606229          771    France    Male   39       5       0.00
# 9996  2025    15569892          516    France    Male   35      10   57369.61
# 9997  2025    15584532          709    France  Female   36       7       0.00
# 9998  2025    15682355          772   Germany    Male   42       3   75075.31
# 9999  2025    15628319          792    France  Female   28       4  130142.79
#
# ...

# %%
Bank_data.groupby("CreditScore_group")["Exited"].value_counts(normalize = True).loc[:,1]*100
# Out:
# CreditScore_group
# Low       21.121365
# Medium    18.815186
# High      20.053763
# Name: proportion, dtype: float64

# %%
Bank_data.to_csv("Bank_data_new_file.csv",index=False)

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\rupes\\Documents\\Python practice\\Panda'

# %%
Bank_data.tail()
# Out:
#       Year  CustomerId  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 9995  2025    15606229          771    France    Male   39       5       0.00
# 9996  2025    15569892          516    France    Male   35      10   57369.61
# 9997  2025    15584532          709    France  Female   36       7       0.00
# 9998  2025    15682355          772   Germany    Male   42       3   75075.31
# 9999  2025    15628319          792    France  Female   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 9995              2          1               0         96270.64       0
# 9996              1          1               1        101699.77       0
# 9997              1          0               1         42085.58       1
# 9998              2          1               0         92888.52       1
# 9999              1          1               0         38190.78       0
#
#      Age_group CreditScore_group Tenure_group Balance_group
# ...

# %%
Bank_data.to_csv('Bank_data_new_file.csv', index=False)
